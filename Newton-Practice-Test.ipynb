# %%
import os
os.getcwd()
# Out:
# '/home/jovyan/newton-practice'

# %%
import newton
import numpy as np
newton.new_optimize(5, lambda x: (x**4/4)-x**3-x )
# Out:
# {'x:': 5, 'f(x_new)': 3.911113350399482}
